# %%
import pandas as pd

# %%
df = pd.read_csv('Ecommerce Purchases')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %% [markdown]
# **How many rows and columns are there?**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  str
#  1   Lot               10000 non-null  str
#  2   AM or PM          10000 non-null  str
#  3   Browser Info      10000 non-null  str
#  4   Company           10000 non-null  str
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  str
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  str
#  9   Email             10000 non-null  str
#  10  Job               10000 non-null  str
#  11  IP Address        10000 non-null  str
#  12  Language          10000 non-null  str
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), str(11)
# memory usage: 1.1 MB

# %% [markdown]
# **What is the average Purchase Price?**

# %%
df['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %% [markdown]
# **What were the highest and lowest purchase prices?**

# %%
df['Purchase Price'].max()
# Out:
# np.float64(99.99)

# %%
df['Purchase Price'].min()
# Out:
# np.float64(0.0)

# %%
df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# **How many people have English 'en' as their Language of choice on the website?**

# %%
df[df['Language'] == 'en']['Language'].count()
# df[df['Language'] == 'en']
# Out:
# np.int64(1098)

# %% [markdown]
# **How many people have the job title of "Lawyer" ?**

# %%
df['Job'].nunique()
# Out:
# 623

# %%
df[df['Job'] == 'Lawyer']['Job'].count()
# Out:
# np.int64(30)

# %% [markdown]
# **How many people made the purchase during the AM and how many people made the purchase during PM ?**

# %%
df['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
#                                  ..
# Special effects artist            7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %% [markdown]
# **What are the 5 most common Job Titles?**

# %%
df['Job'].value_counts().head(5)
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
# Name: count, dtype: int64

# %% [markdown]
# **Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?**

# %%
df[df['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# **What is the email of the person with the following Credit Card Number: 675957666125**

# %%
df[df["Credit Card"] == 675957666125]['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: str

# %% [markdown]
# **How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
df[(df['CC Provider']=='American Express') & (df['Purchase Price']>95)].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\ops\array_ops.py:374, in na_logical_op(x, y, op)
#     365 try:
#     366     # For exposition, write:
#     367     #  yarr = isinstance(y, np.ndarray)
#    (...)    372     # Then Cases where this goes through without raising include:
#     373     #  (xint or xbool) and (yint or bool)
# --> 374     result = op(x, y)
#     375 except TypeError:
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\roperator.py:55, in rand_(left, right)
#      54 def rand_(left, right):
# ---> 55     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\ops\array_ops.py:388, in na_logical_op(x, y, op)
#     387 try:
# --> 388     result = libops.scalar_binop(x, y, op)
#     389 except (
#     390     TypeError,
#     391     ValueError,
#    (...)    394     NotImplementedError,
#     395 ) as err:
#
# File pandas/_libs/ops.pyx:178, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'bool'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df[df['CC Provider']=='American Express' & (df['Purchase Price']>95)].count()
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\arraylike.py:76, in OpsMixin.__rand__(self, other)
#      74 @unpack_zerodim_and_defer("__rand__")
#      75 def __rand__(self, other):
# ---> 76     return self._logical_method(other, roperator.rand_)
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\series.py:6746, in Series._logical_method(self, other, op)
#    6743 lvalues = self._values
#    6744 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6746 res_values = ops.logical_op(lvalues, rvalues, op)
#    6747 return self._construct_result(res_values, name=res_name, other=other)
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\ops\array_ops.py:464, in logical_op(left, right, op)
#     460 else:
#     461     # i.e. scalar
#     462     is_other_int_dtype = lib.is_integer(rvalues)
# --> 464 res_values = na_logical_op(lvalues, rvalues, op)
#     466 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     467 #   integer dtypes.  Otherwise these are boolean ops
#     468 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File ~\Desktop\Data Science Resources\Day 01\code resources\env\Lib\site-packages\pandas\core\ops\array_ops.py:397, in na_logical_op(x, y, op)
#     389         except (
#     390             TypeError,
#     391             ValueError,
#    (...)    394             NotImplementedError,
#     395         ) as err:
#     396             typ = type(y).__name__
# --> 397             raise TypeError(
#     398                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     399                 f"and scalar of type [{typ}]"
#     400             ) from err
#     402 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [bool] array and scalar of type [bool]

# %% [markdown]
# **How many people have a credit card that expires in 2025?**

# %%
df.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
#    Purchase Price
# 0           98.14
# 1           70.73

# %%
def return_str(txt):
    return txt[3:]
df['CC Exp Date'].apply(return_str)
sum(df['CC Exp Date'].apply(lambda x: x[3:]) == '25')

df[df['CC Exp Date'].apply(lambda x: x[3:]) == '25']
# df['CC Exp Date']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# 5     Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_8_5...
# 7     Mozilla/5.0 (X11; Linux i686) AppleWebKit/5350...
# 13    Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_8...
# 15    Opera/8.95.(Windows NT 5.0; en-US) Presto/2.9....
# ...                                                 ...
# 9955  Mozilla/5.0 (compatible; MSIE 8.0; Windows CE;...
# 9963  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 9993  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_8...
# 9994  Opera/9.68.(X11; Linux x86_64; sl-SI) Presto/2...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                         Company       Credit Card CC Exp Date  \
# 4     Brown, Watson and Andrews  6011456623207998       10/25
# 5                Silva-Anderson    30246185196287       07/25
# 7              Marshall-Collins      561252141909       06/25
# 13                   Keller PLC  4603635169938574       01/25
# 15                Garcia-Steele   180069437020404       04/25
# ...                         ...               ...         ...
# 9955                Russell PLC     4716539058450       02/25
# 9963    Brown, Gentry and White  4295151255424068       07/25
# 9993             Colon and Sons    30025560104631       10/25
# 9994               Ritter-Smith  3112186784121077       01/25
# 9996   Hale, Collins and Wilson   210033169205009       07/25
#
#       CC Security Code                  CC Provider  \
# 4                  678  Diners Club / Carte Blanche
# 5                 7169                     Discover
# 7                  256                VISA 13 digit
# 13                 557                VISA 16 digit
# 15                 404  Diners Club / Carte Blanche
# ...                ...                          ...
# 9955              2805                 JCB 16 digit
# 9963               764                 JCB 15 digit
# 9993               629                      Maestro
# 9994              1823                      Maestro
# 9996               207                 JCB 16 digit
#
#                                       Email  \
# 4               christopherwright@gmail.com
# 5                         ynguyen@gmail.com
# 7                      phillip48@parks.info
# 13                      caitlin57@yahoo.com
# 15                       amanda39@yahoo.com
# ...                                     ...
# 9955  matthewcontreras@bradshaw-skinner.com
# 9963                       zjames@gmail.com
# 9993              chelseawilliams@lopez.biz
# 9994                     iroberts@gmail.com
# 9996                     mary85@hotmail.com
#
#                                        Job      IP Address Language  \
# 4                              Fine artist    24.140.33.94       es
# 5                        Fish farm manager   55.96.152.147       ru
# 7                          Event organiser  224.247.97.150       pt
# 13    Accountant, chartered public finance    84.212.92.11       it
# 15                          Retail manager   53.176.235.33       el
# ...                                    ...             ...      ...
# 9955                            Podiatrist  88.110.181.120       zh
# 9963                               Surgeon  171.24.198.172       en
# 9993          Designer, exhibition/display   177.46.82.128       el
# 9994             Education officer, museum   242.44.112.18       zh
# 9996                       Energy engineer  121.133.168.51       pt
#
#       Purchase Price
# 4              77.82
# 5              25.15
# 7              44.25
# 13              8.93
# 15             71.78
# ...              ...
# 9955           84.09
# 9963           58.17
# 9993           65.61
# 9994           31.85
# 9996           25.63
#
# [1033 rows x 14 columns]

# %% [markdown]
# **What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)**

# %%
df['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %% [markdown]
# # Great Job!
