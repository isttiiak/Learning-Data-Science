# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression   # for MNAR salary imputation
from sklearn.impute import KNNImputer               # for KNN imputation
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('../data/hr_dataset_messy.csv')

# %%
# ── 1. Size and shape ──────────────────────────────────────────
print("SHAPE:", df.shape)

# %%
# ── 2. Column names + data types ──────────────────────────────
print("\nDTYPES:")
print(df.dtypes)

# %%
# ── 3. First look at values ────────────────────────────────────
print("\nSAMPLE ROWS:")
df.head(10)

# %%
# ── 4. Full missing value report ──────────────────────────────

missing = pd.DataFrame({
    'missing_count': df.isnull().sum(),
    'missing_%': (df.isnull().sum() / len(df) * 100).round(2)
})

print(f"Missing Data with percentage:")
print(missing[missing['missing_count'] > 0])

# %%
# different way to calculate percentage

miss_per = (df.isnull().mean() * 100).round(2)

miss_per[miss_per > 0]

# %%
# ── 5. Numeric columns — catch outliers early ─────────────────
df.describe()
