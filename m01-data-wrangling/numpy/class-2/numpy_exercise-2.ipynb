# %%
import numpy as np

# %%
lst = [1,2,3]

# %%
type(lst)

# %%
arr = np.array(lst)

# %%
lst

# %%
arr

# %%
type(arr)

# %%
lst[0] + lst[1]

# %%
arr[0] + arr[1]

# %%
lst

# %%
np.arange(stop=7,step=2)

# %%
np.zeros((5,4),dtype=int)

# %%
np.ones((5,4),dtype=int)

# %%
np.full((5,4),8)

# %%
np.eye(5)

# %%
np.linspace(0,10,5)

# %%
np.random.rand(100)

# %%
np.random.randn(20)

# %%
np.random.randint(1,10,(5,4))

# %%
arr2 = np.random.randn(50)

# %%
arr2.max()

# %%
arr2

# %%
arr2.argmax()

# %%
arr2.min()

# %%
arr2.argmin()

# %%
arr3 = arr2.reshape(10,5)

# %%
arr3

# %%
arr3.min()

# %%
arr3.max()

# %%
arr3.argmax(axis=1)

# %%
arr4 = np.random.randint(1,20,(10,5))

# %%
arr4

# %%
arr4.argmax(axis=0)

# %%
arr4.argmax()

# %%
row, column = np.unravel_index(arr4.argmin(), arr4.shape)

# %%
np.__version__

# %%
row,column

# %%
arr4.shape

# %%
# !pip list -V
